# %%
import numpy as np
import pandas as pd

import googlemaps
import gmplot
import folium

import matplotlib.pyplot as plt

# %%
df_nodes = pd.read_table('new_nodes.txt', sep=' ', names=['index', 'names', 'lat', 'lng'])
df_nodes
# Out:
#      index                              names        lat         lng
# 0        0                      Cafe Ventanas  32.886031 -117.242574
# 1        1                       Canyon Vista  32.883889 -117.233333
# 2        2                           Che Cafe  32.872892 -117.239281
# 3        3                           Club Med  32.875151 -117.235213
# 4        4           Goody's Place and Market  32.882899 -117.240411
# ..     ...                                ...        ...         ...
# 275    275          Study Abroad UC San Diego  32.879028 -117.234730
# 276    276             TMC Office of Res Life  32.874968 -117.241718
# 277    277                      Triton Center  32.882063 -117.235589
# 278    278  University Centers Event Services  32.879693 -117.235563
# 279    279       Willaim J. von Liebig Center  32.881393 -117.234327
#
# [280 rows x 4 columns]

# %%
locations = folium.map.FeatureGroup()

for lat, lng, in zip(df_nodes['lat'], df_nodes['lng']):
    locations.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=1,
            color='red',
        )
    )

# Add incidents to map
ucsd_map = folium.Map(location=[df_nodes['lat'][0], df_nodes['lng'][0]], zoom_start=50)
ucsd_map.add_child(locations)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# selected_points = [1, 26, 51, 76, 101, 126, 151, 176, 201, 226]

selected_points = [226]
                   
locations = folium.map.FeatureGroup()

for i in selected_points:
    lat, lng = df_nodes.loc[i, 'lat'], df_nodes.loc[i,'lng']
    locations.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=4,
            color='blue',
        )
    )

# Add incidents to map
ucsd_map = folium.Map(location=[df_nodes['lat'][i], df_nodes['lng'][i]], zoom_start=70)
ucsd_map.add_child(locations)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
