# %%
f = open("table.txt")

# %%
f = open("table.txt", 'r')
df = open("table.txt", 'w')
line00 = 1
while line00:
    line00 = f.readline()
    line01 = f.readline()
    line02 = f.readline()
    line03 = f.readline()
    line04 = f.readline()
    line05 = f.readline()
    line06 = f.readline()
    line07 = f.readline()
    line08 = f.readline()
    line09 = f.readline()
    line10 = f.readline()
    line11 = f.readline()
    line12 = f.readline()
    line13 = f.readline()
    pos = line01[5:-1]
    print(pos)
    article = line02[9:-1]
    print(article)
    name = line03[6:-1]
    print(name)
    image = line04[7:-1]
    print(image)
    lat = line07[5:-1]
    print(lat)
    lon = line08[5:-1]
    print(lon)
    description = line10[14:-1].replace('[[', '').replace(']]', '').replace('<ref>/*</ref>', '')
    print(description)
    print('')
f.close()
# Out:
# 1
# 69th Regiment Armory
# 69th Regiment Armory
# 69th-regiment-armory.JPG
# 40.741648
# -73.983607
# Home of the watershed Armory Show in 1913, which introduced America to modern art
#
# 2
# Admiral David Glasgow Farragut Gravesite
# Admiral David Glasgow Farragut Gravesite
# Admiral David Farragut Monument 1024.jpg
# 40.892165
# -73.865860
# Only intact known property directly associated with Admiral David Farragut
#
# 3
# African Burial Ground National Monument
# African Burial Ground
# African Burial Ground.jpg
# 40.714558
# -74.004384
# Dedicated as National Monument on October 5, 2007; burial site in Lower Manhattan of over 400 Africans from the 17th and 18th centuries
#
# 4
# United States Lightship LV-87
# Ambrose (lightship)
# Ambrose Lightship.jpg
# 40.704844
# -74.002467
# Lightship, several miles offshore, that marked Ambrose Channel into New York Harbor, now at South Street Seaport Museum.
#
# 5
# American Stock Exchange Building
# American Stock Exchange
# AMEX.jpg
# ...
