# %%
import requests        #导入requests包
from bs4 import    BeautifulSoup

import pandas as pd

from cv2 import *
import urllib
import numpy as np
import requests as req
from PIL import Image
from io import BytesIO
from skimage import io

# %%
df = pd.DataFrame(columns=['name', 'lat', 'lon', 'description', 'image_url'])

# %%
url = 'https://en.wikipedia.org/wiki/List_of_tourist_attractions_on_Long_Island'
strhtml = requests.get(url)
soup = BeautifulSoup(strhtml.text,'lxml')
    
for location in range(2,24):
    data = soup.select('#mw-content-text > div.mw-parser-output > blockquote > center > table > tbody > tr:nth-child(' + str(location) + ') > td:nth-child(2) > a')
    if not data:
        continue
    item = data[0]
    name = item.get_text()
    print('name: ' + name)
    
    landmark_src = item.get('href')
    url = 'https://en.wikipedia.org' + landmark_src
    strhtml = requests.get(url)
    landmark_soup = BeautifulSoup(strhtml.text,'lxml')
    data = landmark_soup.select('#mw-content-text > div.mw-parser-output')
    item = data[0]
    geocode = item.find_all(name="span", attrs={"class" :"geo"})[0].get_text()
    geocode = geocode.split('; ')
    lat = geocode[0]
    lon = geocode[1]
    print('location: ' + str(lat) + ' ' + str(lon))

    data = soup.select('#mw-content-text > div.mw-parser-output > blockquote > center > table > tbody > tr:nth-child(' + str(location) + ') > td:nth-child(4)')
    if not data:
        continue
    item = data[0]
    description = item.get_text()
    print('description: '+description)

    data = soup.select('#mw-content-text > div.mw-parser-output > blockquote > center > table > tbody > tr:nth-child(' + str(location) + ') > td:nth-child(3) > a > img')
    if not data:
        continue
    item = data[0]
    image = item.get('alt')
    url = 'https://en.wikipedia.org/wiki/File:' + image
    strhtml = requests.get(url)
    image_soup = BeautifulSoup(strhtml.text,'lxml')
    data = image_soup.select('#mw-content-text > div.fullMedia > p > a')
    item = data[0]
    img_src = 'https:'+item.get('href')
    print('img_src: ' + img_src)
    print(' ')
    
    df = df.append({
        'name': name,
        'image_url': img_src,
        'description': description,
        'lat': lat,
        'lon':lon
    }
        , ignore_index=True)
# Out:
# name: Brooklyn Museum
# location: 40.671306 -73.963750
# description: Located on Long Island in New York City's borough of Brooklyn, it is the second-largest art museum in New York City, and one of the largest in the United States.
# img_src: https://upload.wikimedia.org/wikipedia/commons/d/df/Brooklyn_Museum_June_2008_sunset_jeh.JPG
#
# name: Brooklyn Tabernacle
# location: 40.69083 -73.987444
# description: The Brooklyn Tabernacle is one of New York City's largest churches and Grammy Award winning Choir.
# img_src: https://upload.wikimedia.org/wikipedia/en/0/01/Brooklyn-Tab.jpg
#
# name: Brooklyn Bridge
# location: 40.7057 -73.9964
# description: Built in 1874, the Brooklyn Bridge is the oldest existing suspension bridge in the U.S.
# img_src: https://upload.wikimedia.org/wikipedia/commons/e/e2/Pont_de_Brooklyn_de_nuit_-_Octobre_2008_edit.jpg
#
# name: Coney Island
# location: 40.5750 -73.9825
# description: Between about 1880 and World War II, Coney Island was the largest amusement area in the United States; today, it contains two amusement parks and several other attractions clustered around the Riegelmann Boardwalk.
# img_src: https://upload.wikimedia.org/wikipedia/commons/5/58/Nathan%27s_Coney_Island_July_2007.jpg
#
# name: Prospect Park
# location: 40.66167 -73.97083
# description: The country's longest open park meadow, with ancient trees in Brooklyn's only extant forest.
# img_src: https://upload.wikimedia.org/wikipedia/commons/2/23/Long-Meadow-Panorama-M01.jpg
#
# name: Citi Field
# location: 40.75694 -73.84583
# description: The home stadium of the New York Mets baseball team.
# img_src: https://upload.wikimedia.org/wikipedia/commons/1/11/Citi_FIeld_Night.jpg
#
# name: Rockaway Peninsula
# location: 40.58583 -73.81694
# description: Also called The Rockaways, a popular summer resort area since the 1830s, containing the Rockaway Beach and Boardwalk and Jacob Riis Park on its southern shore.
# img_src: https://upload.wikimedia.org/wikipedia/commons/a/ad/Rockaway_Boardwalk_jeh.JPG
#
# name: Unisphere
# location: 40.746426 -73.844819
# description: The symbol of Queens, the Unisphere is a giant globe in Flushing Meadows Park.
# img_src: https://upload.wikimedia.org/wikipedia/commons/7/72/Unisfera_Flushing.jpg
#
# name: Jones Beach
# location: 40.59583 -73.51528
# description: Jones Beach Tower, now a familiar Jones Beach State Park landmark, was modeled on the campanile of St Mark's Basilica in Venice.
# img_src: https://upload.wikimedia.org/wikipedia/commons/b/bc/Jones_Beach_WantaghPkwy_Approach.jpg
#
# name: Nassau Veterans Memorial Coliseum
# location: 40.72278 -73.59056
# description: Former home arena of the New York Islanders hockey team.
# img_src: https://upload.wikimedia.org/wikipedia/commons/c/cd/NVMC_3.jpg
#
# name: Old Westbury Gardens
# location: 40.77389 -73.59639
# description: Charles II - Westbury House, style mansion designed by George A. Crawley, contains 23 rooms. The grounds cover 160 acres.
# img_src: https://upload.wikimedia.org/wikipedia/commons/f/fe/Old_Westbury_Gardens_10.JPG
#
# name: Planting Fields Arboretum State Historic Park
# location: 40.86083 -73.55722
# description: An arboretum and state park covering over 400 acres (160 ha) located in the Village of Upper Brookville in the town of Oyster Bay, New York.
# img_src: https://upload.wikimedia.org/wikipedia/commons/1/19/Plantfield5597.JPG
#
# name: Sagamore Hill
# location: 40.88556 -73.49750
# description: Sagamore Hill was the home of the 26th President of the United States, Theodore Roosevelt, from 1886 until his death in 1919.
# img_src: https://upload.wikimedia.org/wikipedia/commons/9/98/SagamoreHill.JPG
#
# name: Welwyn Preserve
# location: 40.884 -73.639
# description: Welwyn Preserve was the estate of Harold I. Pratt. It is now a 204 acre nature reserve, and the mansion houses a Holocaust museum
# img_src: https://upload.wikimedia.org/wikipedia/commons/7/71/Welwyn_mansion_in_Welwyn_Preserve.JPG
#
# name: American Airpower Museum
# location: 40.73750 -73.41333
# description: The American Airpower Museum, the former site of the Republic factory in Farmingdale, New York, maintains a collection of Republic artifacts, and an array of aircraft spanning the many years of the aircraft factory's history.
# name: Bald Hill
# location: 40.843859000 -73.021617000
# description: Bald Hill Memorial is located in Farmingville, NY. This destination pays tribute to U.S. Veterans to honor the men and women that served the country during the Vietnam War.
# img_src: https://upload.wikimedia.org/wikipedia/commons/d/d2/Bald-hill-memorial.jpg
#
# name: Captree State Park
# location: 40.640 -73.255
# description: A state park located on the south shore off Jones Island (the barrier island that includes Jones Beach), overlooking the Fire Island Inlet Bridge and the westernmost section of Fire Island. Captree is a fisherman's haven and a picnicker's delight.
# img_src: https://upload.wikimedia.org/wikipedia/commons/6/65/Captree_state_park_NY_docks.jpg
#
# name: Fire Island Light
# location: 40.632444 -73.218583
# description: Fire Island Lighthouse is a 180 foot stone tower that began operation in 1858  replacing the 74 foot tower originally built in 1826.
# img_src: https://upload.wikimedia.org/wikipedia/commons/a/ad/Fire_Island_Lighthouse_09.jpg
#
# name: Great South Bay Bridge
# location: 40.67611 -73.27417
# description: The Robert Moses Causeway, over The State Channel and Fire Island inlet bridges to one of Long Island's great Atlantic coast islands such as Fire and Jones Beach Island connecting New York's Ocean Parkway.
# img_src: https://upload.wikimedia.org/wikipedia/commons/b/b9/GreatSouth-B-B.jpg
#
# name: Long Island Game Farm
# location: 40.84833 -72.78889
# description: (Petting Zoo) with over 200 animals. The Long Island Game Farm is one of the island's oldest and most well-known establishments.
# img_src: https://upload.wikimedia.org/wikipedia/commons/7/7e/LI_Game_Farm_Sign%3B_Looking_South.jpg
#
# name: Port Jefferson Harbor
# location: 40.94611 -73.06222
# description: Port Jefferson Harbor continues to attract mariners, visitors, tourists, and families to an area where natural beauty is the setting for a wide variety of activities, including a ferry service to Connecticut.
# img_src: https://upload.wikimedia.org/wikipedia/commons/3/30/Port_Jefferson_Harbor.jpg
#
# name: Splish Splash
# location: 40.92074 -72.72824
# description: Splish Splash is a 96-acre water park in Riverhead, New York.
# img_src: https://upload.wikimedia.org/wikipedia/commons/c/cc/Water_pluss_water.jpg

# %%
df
# Out:
#                                              name           lat  \
# 0                                 Brooklyn Museum     40.671306
# 1                             Brooklyn Tabernacle      40.69083
# 2                                 Brooklyn Bridge       40.7057
# 3                                    Coney Island       40.5750
# 4                                   Prospect Park      40.66167
# 5                                      Citi Field      40.75694
# 6                              Rockaway Peninsula      40.58583
# 7                                       Unisphere     40.746426
# 8                                     Jones Beach      40.59583
# 9               Nassau Veterans Memorial Coliseum      40.72278
# 10                           Old Westbury Gardens      40.77389
# 11  Planting Fields Arboretum State Historic Park      40.86083
# 12                                  Sagamore Hill      40.88556
# 13                                Welwyn Preserve        40.884
# 14                                      Bald Hill  40.843859000
# 15                             Captree State Park        40.640
# 16                              Fire Island Light     40.632444
# 17                         Great South Bay Bridge      40.67611
# 18                          Long Island Game Farm      40.84833
# 19                          Port Jefferson Harbor      40.94611
# 20                                  Splish Splash      40.92074
#
#               lon                                        description  \
# 0      -73.963750  Located on Long Island in New York City's boro...
# 1      -73.987444  The Brooklyn Tabernacle is one of New York Cit...
# 2        -73.9964  Built in 1874, the Brooklyn Bridge is the olde...
# 3        -73.9825  Between about 1880 and World War II, Coney Isl...
# 4       -73.97083  The country's longest open park meadow, with a...
# 5       -73.84583  The home stadium of the New York Mets baseball...
# 6       -73.81694  Also called The Rockaways, a popular summer re...
# 7      -73.844819  The symbol of Queens, the Unisphere is a giant...
# 8       -73.51528  Jones Beach Tower, now a familiar Jones Beach ...
# 9       -73.59056  Former home arena of the New York Islanders ho...
# 10      -73.59639  Charles II - Westbury House, style mansion des...
# 11      -73.55722  An arboretum and state park covering over 400 ...
# 12      -73.49750  Sagamore Hill was the home of the 26th Preside...
# 13        -73.639  Welwyn Preserve was the estate of Harold I. Pr...
# 14  -73.021617000  Bald Hill Memorial is located in Farmingville,...
# 15        -73.255  A state park located on the south shore off Jo...
# 16     -73.218583  Fire Island Lighthouse is a 180 foot stone tow...
# 17      -73.27417  The Robert Moses Causeway, over The State Chan...
# 18      -72.78889  (Petting Zoo) with over 200 animals. The Long ...
# 19      -73.06222  Port Jefferson Harbor continues to attract mar...
# 20      -72.72824  Splish Splash is a 96-acre water park in River...
#
#                                             image_url
# 0   https://upload.wikimedia.org/wikipedia/commons...
# 1   https://upload.wikimedia.org/wikipedia/en/0/01...
# 2   https://upload.wikimedia.org/wikipedia/commons...
# 3   https://upload.wikimedia.org/wikipedia/commons...
# 4   https://upload.wikimedia.org/wikipedia/commons...
# 5   https://upload.wikimedia.org/wikipedia/commons...
# 6   https://upload.wikimedia.org/wikipedia/commons...
# 7   https://upload.wikimedia.org/wikipedia/commons...
# 8   https://upload.wikimedia.org/wikipedia/commons...
# 9   https://upload.wikimedia.org/wikipedia/commons...
# 10  https://upload.wikimedia.org/wikipedia/commons...
# 11  https://upload.wikimedia.org/wikipedia/commons...
# 12  https://upload.wikimedia.org/wikipedia/commons...
# 13  https://upload.wikimedia.org/wikipedia/commons...
# 14  https://upload.wikimedia.org/wikipedia/commons...
# 15  https://upload.wikimedia.org/wikipedia/commons...
# 16  https://upload.wikimedia.org/wikipedia/commons...
# 17  https://upload.wikimedia.org/wikipedia/commons...
# 18  https://upload.wikimedia.org/wikipedia/commons...
# 19  https://upload.wikimedia.org/wikipedia/commons...
# 20  https://upload.wikimedia.org/wikipedia/commons...

# %%
df.to_csv('LongIsland.csv')

# %%
url = 'https://en.wikipedia.org/wiki/Brooklyn_Museum'
strhtml = requests.get(url)
soup = BeautifulSoup(strhtml.text,'lxml')
i = 0
while True:
    data = soup.select('#mw-content-text > div.mw-parser-output > p:nth-child('+str(i)+')')
    if data:
        break
    i+=1
item = data[0]
description = item.get_text()
print(description)
# Out:
# The Brooklyn Museum is an art museum located in the New York City borough of Brooklyn. At 560,000 square feet (52,000 m2), the museum is New York City's third largest in physical size and holds an art collection with roughly 1.5 million works.[2]
