# %%
import googlemaps

import numpy as np
import pandas as pd

# %%
API_key = 'AIzaSyC9nse_nWqD3A8lLuLSgqTl2_QvfBrgjSI'
gmaps = googlemaps.Client(key=API_key)

# %%
gmaps.reverse_geocode((32.8778021, -117.2372517))[0]['formatted_address']
# Out:
# 'Center Hall, San Diego, CA 92161, USA'

# %%
gmaps.geocode('center hall,San Diego, CA')[0]['formatted_address']
# Out:
# 'Center Hall, San Diego, CA 92161, USA'

# %%
pd.read_csv('NewYorkLandmarks.csv')
# Out:
#      Unnamed: 0                                   article  \
# 0             0                      69th Regiment Armory
# 1             1  Admiral David Glasgow Farragut Gravesite
# 2             2   African Burial Ground National Monument
# 3             3             United States Lightship LV-87
# 4             4          American Stock Exchange Building
# ..          ...                                       ...
# 110         110            Wards Point Archeological Site
# 111         111                 Woodlawn Cemetery (Bronx)
# 112         112                        Woolworth Building
# 113         113                             Wyckoff House
# 114         114                 Wyckoff-Bennett Homestead
#
#                                          name  \
# 0                        69th Regiment Armory
# 1    Admiral David Glasgow Farragut Gravesite
# 2                       African Burial Ground
# 3                         Ambrose (lightship)
# ...

# %%
df = pd.read_csv('table.csv')

# %%
for i in range(df.shape[0]):
    x, y = df.loc[i, 'lat'], df.loc[i, 'lon']
    formatted_address = gmaps.reverse_geocode((x, y))[0]['formatted_address']
    df.loc[i, 'address'] = [formatted_address]
    print('%d / 115 completed: '%(i+1) + formatted_address)
# Out:
# 1 / 115 completed: 88 Lexington Ave, New York, NY 10016, USA
# 2 / 115 completed: Central Ave, Bronx, NY 10470, USA
# 3 / 115 completed: 290 Broadway, New York, NY 10007, USA
# 4 / 115 completed: 89 South St Pier 16, New York, NY 10038, USA
# 5 / 115 completed: 90 Trinity Pl, New York, NY 10006, USA
# 6 / 115 completed: 34-56 107th St, Corona, NY 11368, USA
# 7 / 115 completed: 123 Lexington Ave, New York, NY 10016, USA
# 8 / 115 completed: 2 Hylan Blvd, Staten Island, NY 10305, USA
# 9 / 115 completed: 895 Shore Rd, Bronx, NY 10464, USA
# 10 / 115 completed: 74 Bleecker St, New York, NY 10012, USA
# 11 / 115 completed: 445-465 West St, New York, NY 10014, USA
# 12 / 115 completed: 52 Brooklyn Bridge, New York, NY 10038, USA
# 13 / 115 completed: 1 Pierrepont St, Brooklyn, NY 11201, USA
# 14 / 115 completed: 122 Pierrepont St, Brooklyn, NY 11201, USA
# 15 / 115 completed: 115-24 Grosvenor Rd, Queens, NY 11418, USA
# 16 / 115 completed: 881 7th Ave, New York, NY 10019, USA
# ...

# %%
df.to_csv('NewYorkLandmarks_v2.csv')
